# %% [markdown]
# <a href="https://colab.research.google.com/github/leonis100/project/blob/main/cotacoes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! pip install investpy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 4.4 MB 5.2 MB/s
# ...
#      |████████████████████████████████| 235 kB 45.2 MB/s
# ...
#   Created wheel for investpy: filename=investpy-1.0.8-py3-none-any.whl size=4481592 sha256=d6451207ac3c0be947c3bd0f9259748e0e8c001d3002a9964963f167999acf8f
#   Stored in directory: /root/.cache/pip/wheels/96/a8/a5/0d33c72eaf00b41df7b9dc1e15d2b7c7154b3f1379ed350211
# Successfully built investpy
# ...

# %%
#abrindo bibliotecas

# %%
import matplotlib.pyplot as plt

# %%
import investpy

# %%
search_results= investpy.search_quotes(text = 'magazine', products=['stocks'], countries= ['Brazil'], n_results=50)
# Out:
# ---------------------------------------------------------------------------
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-8-3352c2f715e0> in <module>
# ----> 1 search_results= investpy.search_quotes(text = 'magazine', products=['stocks'], countries= ['Brazil'], n_results=50)
#
# /usr/local/lib/python3.7/dist-packages/investpy/search.py in search_quotes(text, products, countries, n_results)
#     159         if req.status_code != 200:
#     160             raise ConnectionError(
# --> 161                 f"ERR#0015: error {req.status_code}, try again later."
#     162             )
#     163
#
# ConnectionError: ERR#0015: error 403, try again later.

# %%
for search_results in search_results:
  print (search_results)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-ce1bebdc10c1> in <module>
# ----> 1 for search_results in search_results:
#       2   print (search_results)
#
# NameError: name 'search_results' is not defined

# %%
magazine = search_results.retrieve_historical_data(from_date='01/01/2022', to_date='20/06/2022')

# %%
magazine.head()

# %%
magazine['Close'].plot()

# %%
magazine.to_excel('magalu.xls')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-2bc4b7deaf31> in <module>
# ----> 1 magazine.to_excel('magalu.xls')
#
# NameError: name 'magazine' is not defined

# %%
#indíces

# %%
search_results= investpy.search_quotes(text = 'bvsp', products=['indices'], countries= ['Brazil'], n_results=50)

# %%
for search_results in search_results[0:1]:
  print (search_results)
# Out:
# {"id_": 17920, "name": "Bovespa", "symbol": "BVSP", "country": "brazil", "tag": "/indices/bovespa", "pair_type": "indices", "exchange": "BM&FBovespa"}

# %%
ibovespa = search_results.retrieve_historical_data(from_date='01/01/2014', to_date='01/06/2021')

# %%
ibovespa['Close'].plot()

# %% [markdown]
# etfs

# %%
bove11= investpy.get_etf_historical_data(etf= 'Ishares Ibovespa', country='brazil', from_date='01/01/2014', to_date='01/01/2022')

# %%
bove11.head
# Out:
# <bound method NDFrame.head of               Open    High     Low   Close   Volume Currency     Exchange
# Date
# 2014-01-02   50.23   50.27   49.06   49.08  1001210      BRL  BM&FBovespa
# 2014-01-03   49.10   49.47   49.05   49.26  1227270      BRL  BM&FBovespa
# 2014-01-06   49.26   49.99   49.20   49.84   702060      BRL  BM&FBovespa
# 2014-01-07   49.55   50.29   49.23   49.23  1304100      BRL  BM&FBovespa
# 2014-01-08   49.25   49.59   49.21   49.28   951950      BRL  BM&FBovespa
# ...            ...     ...     ...     ...      ...      ...          ...
# 2021-12-23  101.60  101.60  100.71  100.85  5047637      BRL  BM&FBovespa
# 2021-12-27  101.40  101.80  100.95  101.60  5274352      BRL  BM&FBovespa
# 2021-12-28  101.83  101.83  100.59  101.06  7167734      BRL  BM&FBovespa
# 2021-12-29  101.24  101.35   99.94  100.25  7343838      BRL  BM&FBovespa
# 2021-12-30  100.81  101.45  100.29  100.80  3404622      BRL  BM&FBovespa
#
# [1978 rows x 7 columns]>

# %%
bove11['Close'].plot()

# %% [markdown]
# #commodite

# %%
search_results= investpy.search_quotes(text = 'soy', products=['commodities'], countries= ['Brazil'], n_results=50)

# %%
for search_results in search_results[0:1]:
  print (search_results)
# Out:
# {"id_": 964523, "name": "US Soybeans Futures", "symbol": "SJCc1", "country": null, "tag": "/commodities/us-soybeans?cid=964523", "pair_type": "commodities", "exchange": "BM&FBovespa"}

# %%
soja = search_results.retrieve_historical_data(from_date='01/01/2014', to_date='01/06/2021')

# %%
soja['Close'].plot()

# %%
soja.head
# Out:
# <bound method NDFrame.head of              Open   High    Low  Close  Volume  Change Pct
# Date
# 2014-01-02  28.05  28.05  28.05  28.00       2       -2.95
# 2014-01-03  27.94  27.94  27.94  28.03     215        0.11
# 2014-01-06  28.20  28.20  28.20  28.15       2        0.43
# 2014-01-07  28.14  28.20  28.14  28.13      22       -0.07
# 2014-01-08  27.98  27.98  27.98  27.98       0       -0.53
# ...           ...    ...    ...    ...     ...         ...
# 2021-05-26  33.20  33.57  32.86  33.12     171       -0.63
# 2021-05-27  33.03  33.94  33.03  33.94     236        2.48
# 2021-05-28  34.24  36.65  29.78  33.79      89       -0.44
# 2021-05-31  34.24  36.65  29.78  33.74      89       -0.14
# 2021-06-01  34.10  36.65  29.78  34.14     336        1.18
#
# [1823 rows x 6 columns]>

# %%
soja.to_excel('soja3.xls')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   """Entry point for launching an IPython kernel.

# %%
search_results= investpy.search_quotes(text = 'lumber', products=['commodities'], countries= ['united states'], n_results=50)

# %%
for search_results in search_results[0:1]:
  print (search_results)
# Out:
# {"id_": 959198, "name": "Lumber Futures", "symbol": "LBc1", "country": null, "tag": "/commodities/lumber", "pair_type": "commodities", "exchange": "CME"}

# %%
lumber = search_results.retrieve_historical_data(from_date='01/01/2014', to_date='20/05/2022')

# %%
lumber['Close'].plot()

# %%
search_results= investpy.search_quotes(text = 'wheat', products=['commodities'], countries= ['united states'], n_results=50)

# %%
for search_results in search_results[0:1]:
  print (search_results)
# Out:
# {"id_": 8917, "name": "US Wheat Futures", "symbol": "ZW", "country": null, "tag": "/commodities/us-wheat", "pair_type": "commodities", "exchange": ""}

# %%
wheat = search_results.retrieve_historical_data(from_date='01/01/2022', to_date='20/05/2022')

# %%
wheat['Close'].plot()

# %%
bitcoin = investpy.get_crypto_historical_data(crypto='bitcoin',from_date='01/01/2022', to_date='20/06/2022')

# %%
bitcoin['Close'].plot()

# %%
dogecoin = investpy.get_crypto_historical_data(crypto='dogecoin',from_date='01/01/2022', to_date='20/06/2022')

# %%
dogecoin['Close'].plot()
