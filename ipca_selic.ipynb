# %% [markdown]
# <a href="https://colab.research.google.com/github/leonis100/project/blob/main/ipca_selic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install python-bcb
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 62 kB 925 kB/s
# ...
#      |████████████████████████████████| 84 kB 3.5 MB/s
# ...
#      |████████████████████████████████| 12.2 MB 34.6 MB/s
# ...
#      |████████████████████████████████| 68 kB 6.6 MB/s
# ...
#      |████████████████████████████████| 58 kB 6.1 MB/s
# ...
#      |████████████████████████████████| 80 kB 8.8 MB/s
# ...
#   Attempting uninstall: requests
#     Found existing installation: requests 2.23.0
#     Uninstalling requests-2.23.0:
#       Successfully uninstalled requests-2.23.0
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.3.5
#     Uninstalling pandas-1.3.5:
#       Successfully uninstalled pandas-1.3.5
# ...

# %%
from bcb import sgs
import pandas as pd
from matplotlib import pyplot as plt

# %%
selic = sgs.get(('selic', 432), start = '2016-01-01',end='2022-11-12')
ipca=sgs.get(('ipca',433),start='2016-01-01',end='2022-11-12')

# %%
plt.style.use('ggplot')
ipca.plot(figsize = (10, 10))
plt.title('IPCA-%a.a')
# Out:
# Text(0.5, 1.0, 'IPCA-%a.a')

# %%
plt.style.use('ggplot')
selic.plot(figsize = (10, 10))
plt.title("Taxa de juros - Meta Selic definida pelo Copom - %a.a")
# Out:
# Text(0.5, 1.0, 'Taxa de juros - Meta Selic definida pelo Copom - %a.a')

# %%
selic.to_excel('selic.xlsx')

# %%
plt.savefig('selic2.plt.png', dpi=300)
