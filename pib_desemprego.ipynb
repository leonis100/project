# %% [markdown]
# <a href="https://colab.research.google.com/github/leonis100/project/blob/main/pib_desemprego.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install investpy
# !pip install openpyxl
# !pip install wbgapi
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import wbgapi as wb
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
wb.economy.coder(['CHINA', 'INDIA', 'United States of America', 'INDONESIA', 'Pakistan','NIGERIA','BRAZIL','BANGLADESH','RUSSIA','MEXICO'])
# Out:
# ORIGINAL NAME             WBG NAME            ISO_CODE
# ------------------------  ------------------  ----------
# CHINA                     China               CHN
# INDIA                     India               IND
# United States of America  United States       USA
# INDONESIA                 Indonesia           IDN
# Pakistan                  Pakistan            PAK
# NIGERIA                   Nigeria             NGA
# BRAZIL                    Brazil              BRA
# BANGLADESH                Bangladesh          BGD
# RUSSIA                    Russian Federation  RUS
# MEXICO                    Mexico              MEX

# %%
#pib dos dez países mais populosos.
gdp=wb.data.DataFrame('NY.GDP.MKTP.CD',['CHN','IND', "USA",'IDN',"PAK",'NGA','BRA','BGD','RUS','MEX'])

# %%
gdp.head()
# Out:
#                YR1960        YR1961        YR1962        YR1963        YR1964  \
# economy
# BGD      4.274894e+09  4.817580e+09  5.081413e+09  5.319458e+09  5.386055e+09
# BRA      1.703047e+10  1.727594e+10  1.923175e+10  2.328771e+10  2.096373e+10
# CHN      5.971647e+10  5.005687e+10  4.720936e+10  5.070680e+10  5.970834e+10
# IDN               NaN           NaN           NaN           NaN           NaN
# IND      3.702988e+10  3.923244e+10  4.216148e+10  4.842192e+10  5.648029e+10
#
#                YR1965        YR1966        YR1967        YR1968        YR1969  \
# economy
# BGD      5.906637e+09  6.439688e+09  7.253575e+09  7.483685e+09  8.471006e+09
# BRA      2.246552e+10  2.828332e+10  3.108639e+10  3.393046e+10  3.717164e+10
# CHN      7.043627e+10  7.672029e+10  7.288163e+10  7.084654e+10  7.970591e+10
# IDN               NaN           NaN  5.667757e+09  7.076465e+09  8.337423e+09
# IND      5.955485e+10  4.586546e+10  5.013494e+10  5.308546e+10  5.844800e+10
#
# ...

# %%
#pib per capita dos dez países mais populosos
gdp3=wb.data.DataFrame('NY.GDP.PCAP.CD',['CHN','IND', "USA",'IDN',"PAK",'NGA','BRA','BGD','RUS','MEX'])

# %%
gdp3.head()
# Out:
#              YR1960      YR1961      YR1962      YR1963      YR1964  \
# economy
# BGD       84.825334   92.855109   95.047801   96.552206   94.867554
# BRA      232.998762  229.336766  247.834300  291.404006  254.838581
# CHN       89.520542   75.805838   70.909412   74.313643   85.498555
# IDN             NaN         NaN         NaN         NaN         NaN
# IND       83.035102   85.969704   90.276869  101.315165  115.487608
#
#              YR1965      YR1966      YR1967      YR1968      YR1969  ...  \
# economy                                                              ...
# BGD      100.967872  106.855719  116.796316  116.940530  128.607921  ...
# BRA      265.475398  325.173107  348.021103  370.180412  395.441385  ...
# CHN       98.486778  104.324566   96.589532   91.472718  100.129903  ...
# IDN             NaN         NaN   53.338196   64.839180   74.342215  ...
# IND      119.082476   89.757583   96.046330   99.516836  107.182143  ...
#
# ...

# %%
#mulheres desempregadas estimada
desempregof=wb.data.DataFrame('SL.UEM.TOTL.FE.ZS',['CHN','IND', "USA",'IDN',"PAK",'NGA','BRA','BGD','RUS','MEX'])

# %%
desempregof.head()
# Out:
#          YR1960  YR1961  YR1962  YR1963  YR1964  YR1965  YR1966  YR1967  \
# economy
# BGD         NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# BRA         NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# CHN         NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# IDN         NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# IND         NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
#          YR1968  YR1969  ...  YR2012  YR2013  YR2014  YR2015  YR2016  YR2017  \
# economy                  ...
# BGD         NaN     NaN  ...   6.599   7.588   7.482   7.418   7.357   6.710
# BRA         NaN     NaN  ...   9.067   8.776   8.115  10.060  13.466  14.718
# CHN         NaN     NaN  ...   3.962   3.980   3.998   4.016   3.930   3.853
# IDN         NaN     NaN  ...   4.786   4.272   3.882   4.423   3.869   3.599
# IND         NaN     NaN  ...   5.571   5.548   5.526   5.491   5.447   5.357
#
# ...

# %%
#homem desemprego estimado
desempregom=wb.data.DataFrame('SL.UEM.TOTL.MA.ZS',['CHN','IND', "USA",'IDN',"PAK",'NGA','BRA','BGD','RUS','MEX'])

# %%
desempregom.head()
# Out:
#          YR1960  YR1961  YR1962  YR1963  YR1964  YR1965  YR1966  YR1967  \
# economy
# BGD         NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# BRA         NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# CHN         NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# IDN         NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# IND         NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
#          YR1968  YR1969  ...  YR2012  YR2013  YR2014  YR2015  YR2016  YR2017  \
# economy                  ...
# BGD         NaN     NaN  ...   3.195   3.226   3.174   3.146   3.118   3.335
# BRA         NaN     NaN  ...   5.820   5.670   5.594   7.218  10.207  11.369
# CHN         NaN     NaN  ...   5.051   5.074   5.097   5.120   5.011   4.913
# IDN         NaN     NaN  ...   4.275   4.382   4.153   4.563   4.569   4.059
# IND         NaN     NaN  ...   5.371   5.390   5.412   5.420   5.417   5.359
#
# ...

# %%
#desemprego total estimmado
desemprego_total=wb.data.DataFrame('SL.UEM.TOTL.ZS',['CHN','IND', "USA",'IDN',"PAK",'NGA','BRA','BGD','RUS','MEX'])

# %%
desemprego_total.head()
# Out:
#          YR1960  YR1961  YR1962  YR1963  YR1964  YR1965  YR1966  YR1967  \
# economy
# BGD         NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# BRA         NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# CHN         NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# IDN         NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# IND         NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
#          YR1968  YR1969  ...  YR2012  YR2013  YR2014  YR2015  YR2016  YR2017  \
# economy                  ...
# BGD         NaN     NaN  ...   4.119   4.430   4.384   4.366   4.350   4.370
# BRA         NaN     NaN  ...   7.190   6.980   6.660   8.430  11.600  12.820
# CHN         NaN     NaN  ...   4.570   4.590   4.610   4.630   4.530   4.440
# IDN         NaN     NaN  ...   4.470   4.340   4.050   4.510   4.300   3.880
# IND         NaN     NaN  ...   5.414   5.424   5.436   5.435   5.423   5.358
#
# ...

# %%
with pd.ExcelWriter('macro122.xlsx') as writer:  
    gdp.to_excel(writer, sheet_name='pib')
    gdp3.to_excel(writer, sheet_name='pib_per_capita')
    desempregof.to_excel(writer, sheet_name='desemprego_f')
    desempregom.to_excel(writer, sheet_name='desemprego_mas')
    desemprego_total.to_excel(writer, sheet_name='desemprego_total')
